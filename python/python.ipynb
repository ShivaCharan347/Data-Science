# %% [markdown]
# ### CapStone Project - S2 - Data Analysis using Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### TASK 1

# %%
#Loaded the movie dataset in the python notebook and displayed
movie_df = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
movie_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
#No.of Rows and Columns
movie_df.shape
# Out:
# (4803, 20)

# %%
movie_df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
movie_df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
movie_df.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
def dtype(df):
    cat = []
    con = []
    for col in df:
        if (df[col].dtypes == "object"):
            cat.append(col)
        else:
            con.append(col)
    return cat, con
cat, con = dtype(movie_df)
table = [cat,con]
print(tabulate({"categorical":cat, "continuous":con}, headers=["Category", "Continuous"]))
# Out:
# Category              Continuous
# --------------------  ------------
# genres                budget
# homepage              id
# keywords              popularity
# original_language     revenue
# original_title        runtime
# overview              vote_average
# production_companies  vote_count
# production_countries
# release_date
# spoken_languages
# status
# tagline
# title

# %%
#Titles & Genres of first 50 movies
a = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv', usecols = ['title', 'genres'])
a.head(50)
# Out:
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# ...

# %% [markdown]
# ### TASK 2

# %%
#Columns having null values
movie_df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
movie_df['homepage'].fillna('default/url', inplace= True)

# %%
 movie_df['tagline'].fillna('default/url', inplace= True)

# %%
 movie_df['release_date'].fillna(method= 'ffill', inplace= True)

# %%
#replaced null values, null value treatment
movie_df['overview'].fillna('routine' ,inplace = True)

# %%
movie_df['runtime'].fillna(movie_df['runtime'].mean() ,inplace = True)

# %%
movie_df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# ### TASK 3

# %%
#Movie Categories having budget greater than $ 220,000
cond = movie_df['budget'] > 220000
t3 = movie_df[cond]
print(t3[['title', 'budget']])
# Out:
#                                          title     budget
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4680                               Malevolence     450000
# 4682                              Super Hybrid   13000000
# 4720                     The Birth of a Nation    8500000
# 4758                                The Signal    4000000
# 4770                       Mutual Appreciation     500000
#
# [3684 rows x 2 columns]

# %% [markdown]
# ### TASK 4

# %%
#Movie Categories having revenue greater than 961,000,000
cond1 = movie_df['revenue'] > 961000000
t4 = movie_df[cond1]
print(t4[['title', 'revenue']])
# Out:
#                                              title     revenue
# 0                                           Avatar  2787965087
# 3                            The Dark Knight Rises  1084939099
# 7                          Avengers: Age of Ultron  1405403694
# 12      Pirates of the Caribbean: Dead Man's Chest  1065659812
# 16                                    The Avengers  1519557910
# 17     Pirates of the Caribbean: On Stranger Tides  1045713802
# 25                                         Titanic  1845034188
# 26                      Captain America: Civil War  1153304495
# 28                                  Jurassic World  1513528810
# 29                                         Skyfall  1108561013
# 31                                      Iron Man 3  1215439994
# 32                             Alice in Wonderland  1025491110
# 36                 Transformers: Age of Extinction  1091405097
# 42                                     Toy Story 3  1066969703
# ...

# %% [markdown]
# ### TASK 5

# %%
#Dropping rows of particular column where value is '0'
df = movie_df[(movie_df['revenue'] != 0) | (movie_df['budget'] != 0)]
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### TASK 6

# %%
#TOP 10 movies with high revenue and top 10 with least budget
t6_high = df.sort_values('revenue', ascending= False).head(10)
print(t6_high[['title', 'revenue']])
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
plt.figure(figsize=(15,7))
plt.bar(t6_high['title'],t6_high['revenue'])
plt.title('Top 10 movies with high Revenue')
plt.show()

# %%
t6_low = df.sort_values('budget').head(10)
print(t6_low[['title', 'budget']])
# Out:
#                                 title  budget
# 1007                    Anna Karenina       0
# 3525                 Standing Ovation       0
# 3541                     Irreversible       0
# 3548                      Headhunters       0
# 4533                 Drinking Buddies       0
# 766   Garfield: A Tail of Two Kitties       0
# 3607                  The Beastmaster       0
# 3620                    Grandma's Boy       0
# 3523                      Khiladi 786       0
# 691                         Wild Hogs       0

# %%
plt.figure(figsize=(15,7))
plt.barh(t6_low['title'],t6_low['budget'])
plt.title('Top 10 movies with least budget')
plt.show()

# %% [markdown]
# ### TASK 7

# %%
#plt.plot(df['popularity'], df['budget'], color= 'black', linestyle = 'dashed')
plt.scatter( df['budget'],df['popularity'] )
plt.show()

# %%
#movies related with movie budget
df['popularity'].corr(df['budget'])
# Out:
# 0.4603584105467269

# %% [markdown]
# ### Weak Positive Correlation

# %% [markdown]
# ## TASK 8

# %%
t8 = df['production_companies'].value_counts()
print(f'Number of times they appear in dataset: ',t8)
# Out:
# Number of times they appear in dataset:  []                                                                                                                                                  100
# [{"name": "Paramount Pictures", "id": 4}]                                                                                                            55
# [{"name": "Universal Pictures", "id": 33}]                                                                                                           40
# [{"name": "Columbia Pictures", "id": 5}]                                                                                                             34
# [{"name": "New Line Cinema", "id": 12}]                                                                                                              31
#                                                                                                                                                    ...
# ...

# %% [markdown]
# ## TASK 9

# %%
t9 = t8.head(25)
t9
# Out:
# []                                                                                                                  100
# [{"name": "Paramount Pictures", "id": 4}]                                                                            55
# [{"name": "Universal Pictures", "id": 33}]                                                                           40
# [{"name": "Columbia Pictures", "id": 5}]                                                                             34
# [{"name": "New Line Cinema", "id": 12}]                                                                              31
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}]                                                                  29
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                      27
# [{"name": "Warner Bros.", "id": 6194}]                                                                               25
# ...

# %% [markdown]
# ### TASK 10

# %%
t10 = df.sort_values('revenue', ascending= False).head(500)
t10
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 1042   48000000                     [{"id": 35, "name": "Comedy"}]
# 41    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 521    60000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
#
#                                       homepage      id  \
# 0                  http://www.avatarmovie.com/   19995
# ...

# %%
def central_tend(col):
    print(f"Mean of {col}: {round(t10[col].mean(),2)}")
    print(f"Median of {col}: {round(t10[col].median(),2)}")
    print(f"Mode of {col}: {t10[col].mode()[0]}")

# %%
central_tend('budget')
plt.boxplot('budget', data=t10)
plt.show()
# Out:
# Mean of budget: 102803736.0
# Median of budget: 95000000.0
# Mode of budget: 150000000

# %%
central_tend('revenue')
plt.boxplot('revenue', data=t10)
plt.show()
# Out:
# Mean of revenue: 458722133.29
# Median of revenue: 363001569.5
# Mode of revenue: 219076518

# %%
central_tend('runtime')
plt.boxplot('runtime', data=t10)
plt.show()
# Out:
# Mean of runtime: 118.63
# Median of runtime: 116.0
# Mode of runtime: 115.0

# %% [markdown]
# ### TASK 11

# %%
#from above task mean of runtime is 118.72
cond2 = df.runtime > 118.72
t11  = df[cond2]
t11[['title', 'runtime']]
# Out:
#                                          title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 4535                             Seven Samurai    207.0
# 4592                               Intolerance    197.0
# 4661                            The Big Parade    151.0
# 4677                                     Three    119.0
# 4720                     The Birth of a Nation    120.0
#
# [1032 rows x 2 columns]
